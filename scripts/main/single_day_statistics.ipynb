# %%
# Init pack

import numpy as np
import torch.nn as nn
import torch
import matplotlib.pyplot as plt
from scipy.stats import linregress
import os, random

plt.rcParams['text.usetex'] = True

psi = np.load('/home/constantino-daniel-boscu/Documents/research/AI-RES/modified-code-main3/data/actual/long_run_310k.npy')

psi = psi[:,1,:]

# Normalization
mean_psi = np.mean(psi, axis=0, keepdims=True)
std_psi = np.std(psi, axis=0, keepdims=True)
psi = (psi - mean_psi) / std_psi

# Pre-processing
lead = 1
trainN = 250000
valN = 50000
index = 63

# Defining the variable ranges
variable_range = [(0,24), (25, 49), (50, 74), (0, 49), (0,74)]

# Select the variable: 0 for real perturbation, 1 for imaginary perturbation, 2 for zonal winds
variable = 3
num_variables = variable_range[variable][1] - variable_range[variable][0] + 1

# Shuffle and map indices
np.random.seed(42)
valid_indices = np.arange(0, trainN - lead)
shuffled_indices = np.random.permutation(valid_indices)

# Now constrain the shuffled indices to the variable range
np_psi_train_input = psi[shuffled_indices, variable_range[variable][0]:variable_range[variable][1]+1]
np_psi_train_label = psi[shuffled_indices + lead, :]

psi_train_input = torch.tensor(np_psi_train_input)
psi_train_label = torch.tensor(np_psi_train_label)

np_psi_val_input = psi[trainN:trainN+valN, variable_range[variable][0]:variable_range[variable][1]+1]
np_psi_val_label = psi[trainN+lead:trainN+valN+lead, :]
psi_val_input = torch.tensor(np_psi_val_input)
psi_val_label =  torch.tensor(np_psi_val_label)

plt.plot(np_psi_val_input[:,-1]) # Real and Imaginary PSI
plt.plot(np_psi_val_label[:,-1]) # Real and Imaginary PSI + Zonal Wind
plt.show()

# %%
# Define the encoder (MLP)
class Encoder(nn.Module):
    def __init__(self, latent_dim, num_neurons):
        super(Encoder, self).__init__()
        self.fc1 = nn.Linear(75, num_neurons)
        self.fc2 = nn.Linear(num_neurons, num_neurons)
        self.fc3 = nn.Linear(num_neurons, num_neurons)
        self.fc4 = nn.Linear(num_neurons, num_neurons)
        self.fc5 = nn.Linear(num_neurons, num_neurons)
        self.fc6 = nn.Linear(num_neurons, num_neurons)
        self.fc_mu = nn.Linear(num_neurons, latent_dim)
        self.fc_logvar = nn.Linear(num_neurons, latent_dim)

    def forward(self, x):
        x = torch.relu(self.fc1(x))
        x = torch.relu(self.fc2(x)) + x
        x = torch.relu(self.fc3(x)) + x
        x = torch.relu(self.fc4(x)) + x
        x = torch.relu(self.fc5(x)) + x
        x = torch.relu(self.fc6(x)) + x
        mu = self.fc_mu(x)
        logvar = self.fc_logvar(x)
        return mu, logvar

# Define the decoder (MLP)
class Decoder(nn.Module):
    def __init__(self, latent_dim, output_dim, condition_dim, num_neurons):
        super(Decoder, self).__init__()
        self.fc1 = nn.Linear(latent_dim + condition_dim, num_neurons)
        self.fc2 = nn.Linear(num_neurons, num_neurons)
        self.fc3 = nn.Linear(num_neurons, num_neurons)
        self.fc4 = nn.Linear(num_neurons, num_neurons)
        self.fc5 = nn.Linear(num_neurons, num_neurons)
        self.fc6 = nn.Linear(num_neurons, num_neurons)
        self.fc_output = nn.Linear(num_neurons, output_dim)

    def forward(self, z, condition):
        z = torch.cat((z, condition), dim=1)  # Concatenate latent vector and condition
        z = torch.relu(self.fc1(z))
        z = torch.relu(self.fc2(z)) + z
        z = torch.relu(self.fc3(z)) + z
        z = torch.relu(self.fc4(z)) + z
        z = torch.relu(self.fc5(z)) + z
        z = torch.relu(self.fc6(z)) + z
        output = self.fc_output(z)
        return output

# Define the VAE model
class ConditionalVAE(nn.Module):
    def __init__(self, latent_dim, output_dim, condition_dim, num_neurons):
        super(ConditionalVAE, self).__init__()
        self.encoder = Encoder(latent_dim, num_neurons)
        self.decoder = Decoder(latent_dim, output_dim, condition_dim, num_neurons)

    def encode(self, x):
        mu, logvar = self.encoder(x)
        return mu, logvar

    def reparameterize(self, mu, logvar):
        std = torch.exp(0.5 * logvar)
        eps = torch.randn_like(std)
        z = mu + eps * std
        return z

    def decode(self, z, condition):
        return self.decoder(z, condition)

    def forward(self, x, condition):
        mu, logvar = self.encode(x)
        z = self.reparameterize(mu, logvar)
        output = self.decode(z, condition)
        return output, mu, logvar

output_dim = 75
latent_dim = 32
condition_dim = num_variables
batch_size = 1024

# %%
def normalize_transition_time(s, dlt, r):
    """
    Normalize the transition time based on the specified delta and reference value.

    Args:
        s (float): The transition time to normalize.
        dlt (float): The delta value for normalization.
        r (float): The reference value for normalization.

    Returns:
        norm (float): The normalized transition time.
    """
    norm = 1 - np.exp(-np.abs((s - r)) / dlt)
    return norm

# Function to calculate transition durations
def calculate_transition_durations(y, u, l):
    """
    Calculate the return periods with user-defined upper and lower bounds.

    Args:
        y (np.array): The time series data.
        u (float): The upper bound for the transition.
        l (float): The lower bound for the transition.

    Returns:
        t_times (list): The list of return periods for transitions.
    """

    t_times = []
    s = None
    above_u = False
    below_l = False
    for i in range(1, len(y)):
        
        if y[i] < l:
            if above_u and s is not None:
                t_times.append(i-s)  
            below_l = True
            above_u = False

        elif y[i] > u:  
            if below_l and s is not None:
                t_times.append(i - s)
                s = None  
            above_u = True
            below_l = False

        if below_l and s is None:
            s = i

        if above_u and s is None:
            s = i
    return t_times

def KL_coefficient(r, p, delta, cycle, KL_by_dim_cycle):
    """
    Calculate the KL divergence between two distributions and normalize it.

    Args:
        r (np.array): Real distribution.
        p (np.array): Predicted distribution.
        delta (float): Delta value for normalization.
        cycle (int): Cycle number for tracking.
        KL_by_dim_cycle (dict): Dictionary to store KL divergence values by dimension and cycle.

    Returns:
        r (np.array): Processed real distribution.
        p (np.array): Processed predicted distribution.
        nkl (float): Normalized KL divergence.
    """
    # Calculating KL divergence
    r = r[:30000, 1, 63]
    p = p[:30000]
    
    rh, b = np.histogram(r, bins=50, density=True)
    ph, _ = np.histogram(p, bins=b, density=True)

    e = 1e-10
    rh += e
    ph += e

    # Calculate KL divergence between the two histograms
    kl = np.sum(rh * np.log(rh / ph))
    nkl = normalize_transition_time(kl, 1, 0)

    print(f"Normalized KL divergence for delta {delta}, cycle {cycle}: {nkl:.6f}")
    KL_by_dim_cycle[delta][cycle].append(nkl)

    return r, p, nkl

def CCDF_fit(p_times, s):
    """
    Calculate the slope of the CCDF of transition times and normalize it.

    Args:
        p_times (list): Transition times from predictions.
        s (float): Real value for normalization.
    
    Returns:
        np_slope (float): Normalized slope of the CCDF.
    """
    # === PREDICTIONS CCDF AND FIT ===
    if len(p_times) > 0 and len(np.unique(p_times)) > 1:
        sp_times = np.sort(p_times)
        p_ccdf = 1 - np.arange(1, len(sp_times) + 1) / len(sp_times)

        p_v_indices = p_ccdf > 0
        px_fit = sp_times[p_v_indices]
        py_fit = np.log(p_ccdf[p_v_indices])

        p_slope, _, *_ = linregress(px_fit, py_fit)
        np_slope = normalize_transition_time(p_slope, 0.005, s)
        return np_slope

    else:
        print("No transitions detected in predictions for CCDF slope evaluation.")

def Mean_and_std_of_predictions(p_times, r_times, dlt, cc, transitions_by_dim_cycle, transitions_normalized_by_dim_cycle, transitions_normalized_std_by_dim_cycle):
    """
    Calculate the mean and standard deviation of transition times from predictions and normalize them.

    Args:
        p_times (list): Transition times from predictions.
        r_times (list): Transition times from real data.
        dlt (float): Delta value for normalization.
        cc (int): Cycle number for tracking.
        transitions_by_dim_cycle (dict): Dictionary to store transition times by dimension and cycle.
        transitions_normalized_by_dim_cycle (dict): Dictionary to store normalized transition times by dimension and cycle.
        transitions_normalized_std_by_dim_cycle (dict): Dictionary to store normalized standard deviations by dimension and cycle.

    Returns:
        npd_mean (float): Normalized mean of transition times.
        npd_std (float): Normalized standard deviation of transition times.
    """
    p_mean = np.mean(p_times)
    p_std = np.std(p_times)

    pd_mean = abs(p_mean - np.mean(r_times))
    pd_std = abs(p_std - np.std(r_times))

    npd_mean = normalize_transition_time(pd_mean, 1000, np.mean(r_times))
    npd_std = normalize_transition_time(pd_std, 1000, np.std(r_times))

    npd_std = 1 if npd_std == 0 else npd_std

    transitions_by_dim_cycle[dlt][cc].append(pd_mean)
    transitions_normalized_by_dim_cycle[dlt][cc].append(npd_mean)
    transitions_normalized_std_by_dim_cycle[dlt][cc].append(npd_std)

    return npd_mean, npd_std

# KL Annealing (Fu et al., 2019)
def frange_cycle_linear(start, stop, n_epoch, n_cycle=4, ratio=0.5):
    """
    Generate a linear schedule for KL annealing over multiple cycles.

    Args:
        start (float): Starting value of the schedule.
        stop (float): Stopping value of the schedule.
        n_epoch (int): Total number of epochs.
        n_cycle (int): Number of cycles for the schedule.
        ratio (float): Ratio of the cycle length to the total number of epochs.

    Returns:
        L (np.array): Array containing the linear schedule values for each epoch.
    """
    L = np.ones(n_epoch)
    period = n_epoch/n_cycle
    step = (stop-start)/(period*ratio) # linear schedule

    for c in range(n_cycle):

        v , i = start , 0
        while v <=stop and (int(i+c*period) < n_epoch):
            L[int(i+c*period)] = v
            v += step
            i += 1
    return L

# %%
# PREP
real_data       = np.load("/home/constantino-daniel-boscu/Documents/research/AI-RES/modified-code-main3/data/actual/long_run_310k.npy")
save_dir        = "/home/constantino-daniel-boscu/Documents/research/AI-RES/modified-code-main3/tests/single_timestep"

num_samples     = 1000
level           = 63
start, end      = (0, 50)

latent_dim      = 32
output_dim      = 75
condition_dim   = 50
num_neurons     = 1024

model_path      = "/home/constantino-daniel-boscu/Documents/research/AI-RES/modified-code-main3/training_cycles/resnet/best_models_kinda/checkpoint_11"

model           = ConditionalVAE(latent_dim, output_dim, condition_dim, num_neurons).cuda()
if os.path.exists(model_path):
    model.load_state_dict(torch.load(model_path))
    print("Loading model from checkpoint...")
model.eval()
# Out:
# Loading model from checkpoint...
# /tmp/ipykernel_27354/3193760071.py:18: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path))
# ...

# %%
upper_bound     = 53.8 / 2.8935
lower_bound     = 7.41
zonal_wind      = real_data[:, 1, 63]
timesteps       = 100

def detect_transitions_A_to_B(u_series, upper, lower):
    transitions = []
    transition_values = []
    i = 0
    while i < len(u_series) - 1:
        if u_series[i-1] > upper and u_series[i] <= upper:
            j = i + 1
            while j < len(u_series) and u_series[j] <= upper:
                if u_series[j] < lower:
                    transitions.append(i)
                    transition_values.append(u_series[i])
                    break
                j += 1
            i = j
        else:
            i += 1
    return np.array(transitions), np.array(transition_values)

def detect_transitions_B_to_A(u_series, upper, lower):
    transitions = []
    transition_values = []
    i = 0
    while i < len(u_series) - 1:
        if u_series[i-1] < lower and u_series[i] >= lower:
            j = i + 1
            while j < len(u_series) and u_series[j] >= lower:
                if u_series[j] > upper:
                    transitions.append(i)
                    transition_values.append(u_series[i])
                    break
                j += 1
            i = j
        else:
            i += 1
    return np.array(transitions), np.array(transition_values)

ssw_indices_A1, ssw_transition_values_A1 = detect_transitions_A_to_B(real_data[:, 1, 63], upper_bound, lower_bound)
ssw_indices_B1, ssw_transition_values_B1 = detect_transitions_B_to_A(real_data[:, 1, 63], upper_bound, lower_bound)

transition_indices = np.union1d(ssw_indices_A1, ssw_indices_B1)
total_len = len(real_data)
non_ssw_indices_A1 = np.where((real_data[:, 1, 63] > upper_bound) & (~np.isin(np.arange(total_len), transition_indices)))[0]
non_ssw_indices_B1 = np.where((real_data[:, 1, 63] < lower_bound) & (~np.isin(np.arange(total_len), transition_indices)))[0]

n_samples = min(len(ssw_indices_A1), len(ssw_indices_A1), len(non_ssw_indices_A1), len(non_ssw_indices_A1))

non_ssw_indices_A1 = np.random.choice(non_ssw_indices_A1, size=n_samples, replace=False)
non_ssw_indices_B1 = np.random.choice(non_ssw_indices_B1, size=n_samples, replace=False)
non_ssw_transition_values_A1 = zonal_wind[non_ssw_indices_A1]
non_ssw_transition_values_B1 = zonal_wind[non_ssw_indices_B1]

X = np.vstack([
        real_data[ssw_indices_A1, 1],
        real_data[ssw_indices_B1, 1],
        real_data[non_ssw_indices_A1, 1],
        real_data[non_ssw_indices_B1, 1],
    ]).astype(np.float32)

labels = (
    ["AB"] * len(ssw_indices_A1) +
    ["BA"] * len(ssw_indices_B1) +
    ["A"] * len(non_ssw_indices_A1) +
    ["B"] * len(non_ssw_indices_B1)
)

print(f"SSW Transitions A to B: {len(ssw_indices_A1)}, Mean Value: {np.mean(ssw_transition_values_A1):.2f}")
print(f"SSW Transitions B to A: {len(ssw_indices_B1)}, Mean Value: {np.mean(ssw_transition_values_B1):.2f}")
print(f"Non-SSW Transitions A: {len(non_ssw_indices_A1)}, Mean Value: {np.mean(non_ssw_transition_values_A1):.2f}")
print(f"Non-SSW Transitions B: {len(non_ssw_indices_B1)}, Mean Value: {np.mean(non_ssw_transition_values_B1):.2f}")

timesteps_num   = 1
time_indices_AB = random.sample(range(0, n_samples-1), timesteps_num)[0]
time_indices_BA = random.sample(range(n_samples, n_samples*2-1), timesteps_num)[0]
time_indices_A = random.sample(range(n_samples*2, n_samples*3-1), timesteps_num)[0]
time_indices_B = random.sample(range(n_samples*3, n_samples*4-1), timesteps_num)[0]
print(f"Randomly sampled time steps: {time_indices_AB, time_indices_BA, time_indices_A, time_indices_B}")
selected_ics = [time_indices_AB, time_indices_BA, time_indices_A, time_indices_B]

ics = []
ics.extend(ssw_indices_A1)
ics.extend(ssw_indices_B1)
ics.extend(non_ssw_indices_A1)
ics.extend(non_ssw_indices_B1)
ics = np.array(ics)
next_time_step = ics + 1

real_current = real_data[ics, 1, :]       
real_next = real_data[next_time_step, 1, :]    

num_of_ics = len(ssw_indices_A1) + len(ssw_indices_B1) + len(non_ssw_indices_A1) + len(non_ssw_indices_B1)
print(num_of_ics, X.shape)

X = (X - mean_psi) / std_psi
X = X[:, :50]

initial_cond = torch.reshape(torch.tensor(X), [num_of_ics, num_variables])
z = torch.zeros([num_of_ics,latent_dim])
save = np.zeros([timesteps, num_of_ics, 75])

for j in range(timesteps):
    with torch.no_grad():
        z = torch.randn_like(z)
        y = model.decode(z.float().cuda(), initial_cond.float().cuda())
        y = y.detach().cpu().numpy()
    save[j, :, :] = y

pred_next_denorm = save * std_psi.squeeze() + mean_psi.squeeze()
# pred_next_denorm = np.mean(pred_next_denorm, axis=0)

# 199 points(minimum of # points from each category)
group_bounds = [0, 199, 398, 597, num_of_ics]

# U profiles
U_current_real = real_current[:, 50:75]
U_next_real = real_next[:, 50:75]
U_next_pred = pred_next_denorm[:, :, 50:75]

# Re(Psi) profiles
RePsi_current_real = real_current[:, 0:25]
RePsi_next_real = real_next[:, 0:25]
RePsi_next_pred = pred_next_denorm[:, :, 0:25]

# Im(Psi) profiles
ImPsi_current_real = real_current[:, 25:50]
ImPsi_next_real = real_next[:, 25:50]
ImPsi_next_pred = pred_next_denorm[:, :, 25:50]

# === Differences ===
diff_real = real_next - real_current

# Delta Difference
delta_of_pred = pred_next_denorm - real_current

# === Estimation Error between Differences of Real and Predicted ===

saved_diffs = pred_next_denorm - real_next

types_of_ics = ["Transition Point from Set A to Set B", "Transition Point from Set B to Set A", "Equilibrium Point a", "Equilibrium Point b"]
types_of_icss = ["Transition Points from Set A to Set B", "Transition Points from Set B to Set A", "Equilibrium Points a", "Equilibrium Points b"]

for i in range(4):

    selected_ic = selected_ics[i]

    next_pred = np.mean(pred_next_denorm[:, selected_ic, :], axis = 0)
    pred_std = np.std(pred_next_denorm[:, selected_ic, :], axis = 0)

    diff_real = real_next[selected_ic, :] - real_current[selected_ic, :]
    diff_pred = next_pred - real_current[selected_ic, :]

    mean_delta_of_pred = np.mean(delta_of_pred[:, selected_ic, :], axis = 0)
    std_delta_of_pred = np.std(delta_of_pred[:, selected_ic, :], axis = 0)

    mean_delta_of_pred_over_ics = np.mean(np.mean(delta_of_pred, axis = 0), axis = 0)
    std_delta_of_pred_over_ics = np.std(np.mean(delta_of_pred, axis = 0), axis = 0)

    fig, axes = plt.subplots(3, 3, figsize=(16, 18))  # 3 rows, 3 columns (Profile, Difference, and Estimation Error)

    z_levels_U = np.linspace(0, 70, 25)
    z_levels_RePsi = np.linspace(0, 70, 25)
    z_levels_ImPsi = np.linspace(0, 70, 25)
    zeros = np.zeros((25,))

    axes[0, 0].plot(U_current_real[selected_ic], z_levels_U, 'x-', label="Real Current")
    axes[0, 0].plot(U_next_real[selected_ic], z_levels_U, 'd-', label="Real Next")
    axes[0, 0].plot(next_pred[50:75], z_levels_U, 'sg', label="Mean Predicted Next")
    axes[0, 0].errorbar(next_pred[50:75], z_levels_U, xerr = 2*pred_std[50:75], fmt = '--g', label=r"Values within $2\sigma$")
    axes[0, 0].set_title(f"$U$ Profiles of Singular {types_of_ics[i]}")
    axes[0, 0].set_xlabel("$U$ (m/s)")
    axes[0, 0].set_ylabel("Vertical Levels (km)")
    axes[0, 0].legend(loc = "upper right")

    axes[0, 1].plot(diff_real[50:75], z_levels_U, 'xb', label=r"Real $\Delta$ (Next - Current)")
    axes[0, 1].plot(diff_pred[50:75], z_levels_U, 'or', label=r"Pred $\Delta$ (Next - Current)")
    axes[0, 1].errorbar(mean_delta_of_pred[50:75], z_levels_U, xerr = 2*std_delta_of_pred[50:75], fmt = '--r', label=r"Values within $2\sigma$")
    axes[0, 1].set_title(r"Singular $\Delta U$ (Next - Current)")
    axes[0, 1].set_xlabel(r"$\Delta U$ (m/s)")
    axes[0, 1].set_xlim(-2, 2)
    axes[0, 1].legend(loc = "upper right")

    # --- Re(Psi) ---
    axes[1, 0].plot(RePsi_current_real[selected_ic], z_levels_RePsi, 'x-', label="Real Current")
    axes[1, 0].plot(RePsi_next_real[selected_ic], z_levels_RePsi, 'd-', label="Real Next")
    axes[1, 0].plot(next_pred[0:25], z_levels_RePsi, 'sg', label=" Mean Predicted Next")
    axes[1, 0].errorbar(next_pred[0:25], z_levels_RePsi, xerr = 2*pred_std[0:25], fmt = '--g', label=r"Values within $2\sigma$")
    axes[1, 0].set_title(fr"$Re(\psi)$ Profiles of Singular {types_of_ics[i]}")
    axes[1, 0].set_xlabel(r"$Re(\psi)$")
    axes[1, 0].set_ylabel("Vertical Levels (km)")
    axes[1, 0].legend(loc = "upper right")

    axes[1, 1].plot(diff_real[0:25], z_levels_RePsi, 'xb', label=r"Real $\Delta$ (Next - Current)")
    axes[1, 1].plot(diff_pred[0:25], z_levels_RePsi, 'or', label=r"Pred $\Delta$ (Next - Current)")
    axes[1, 1].errorbar(mean_delta_of_pred[0:25], z_levels_RePsi, xerr = 2*std_delta_of_pred[0:25], fmt = '--r', label=r"Values within $2\sigma$")
    axes[1, 1].set_title(r"Singular $\Delta Re(\psi)$ (Next - Current)")
    axes[1, 1].set_xlabel(r"$\Delta Re(\psi)$")
    axes[1, 1].set_xlim(-2, 2)
    axes[1, 1].legend(loc = "upper right")

    # --- Im(Psi) ---
    axes[2, 0].plot(ImPsi_current_real[selected_ic], z_levels_ImPsi, 'x-', label="Real Current")
    axes[2, 0].plot(ImPsi_next_real[selected_ic], z_levels_ImPsi, 'd-', label="Real Next")
    axes[2, 0].plot(next_pred[25:50], z_levels_ImPsi, 'sg', label="Mean Predicted Next")
    axes[2, 0].errorbar(next_pred[25:50], z_levels_ImPsi, xerr = 2*pred_std[25:50], fmt = '--g', label=r"Values within $2\sigma$")
    axes[2, 0].set_title(fr"$Im(\psi)$ Profiles of Singular {types_of_ics[i]}")
    axes[2, 0].set_xlabel(r"$Im(\psi)$")
    axes[2, 0].set_ylabel("Vertical Levels (km)")
    axes[2, 0].legend(loc = "upper right")

    axes[2, 1].plot(diff_real[25:50], z_levels_ImPsi, 'xb', label=r"Real $\Delta$ (Next - Current)")
    axes[2, 1].plot(diff_pred[25:50], z_levels_ImPsi, 'or', label=r"Pred $\Delta$ (Next - Current)")
    axes[2, 1].errorbar(mean_delta_of_pred[25:50], z_levels_ImPsi, xerr = 2*std_delta_of_pred[25:50], fmt = '--r', label=r"Values within $2\sigma$")
    axes[2, 1].set_title(r"Singular $\Delta Im(\psi)$ (Next - Current)")
    axes[2, 1].set_xlabel(r"$\Delta Im(\psi)$")
    axes[2, 1].set_xlim(-2, 2)
    axes[2, 1].legend(loc = "upper right")

    axes[0, 2].plot(zeros, z_levels_U, 'xb', label = "Ideal Deviation")
    axes[0, 2].plot(mean_delta_of_pred_over_ics[50:75], z_levels_U, 'xr', label = "MD of Predicted")
    axes[0, 2].errorbar(mean_delta_of_pred_over_ics[50:75], z_levels_U, xerr = 2*std_delta_of_pred_over_ics[50:75], fmt = 'r', label = r"Values within $2\sigma$")
    axes[0, 2].legend(loc = 'upper right')
    axes[0, 2].set_title(r"MD of $\widehat{U}$ from 10000 Inferences $\forall$ ICs")
    axes[0, 2].set_xlabel(r"Deviation in $\Delta s$, $U(m/s)$")
    axes[0, 2].set_ylabel("Vertical levels (km)")
    axes[0, 2].set_xlim(-4, 4)

    axes[1, 2].plot(zeros, z_levels_U, 'xb', label = "Ideal Deviation")
    axes[1, 2].plot(mean_delta_of_pred_over_ics[0:25], z_levels_U, 'xr', label = "MD of Predicted")
    axes[1, 2].errorbar(mean_delta_of_pred_over_ics[0:25], z_levels_RePsi, xerr = 2*std_delta_of_pred_over_ics[0:25], fmt = 'r', label = r"Values within $2\sigma$")
    axes[1, 2].legend(loc = 'upper right')
    axes[1, 2].set_title(r"MD of $\widehat{Re(\psi)}$ from 10000 Inferences $\forall$ ICs")
    axes[1, 2].set_xlabel(r"Deviation in $\Delta s$, $Re(\psi)$")
    axes[1, 2].set_ylabel("Vertical levels (km)")
    axes[1, 2].set_xlim(-2, 2)

    axes[2, 2].plot(zeros, z_levels_U, 'xb', label = "Ideal Deviation")
    axes[2, 2].plot(mean_delta_of_pred_over_ics[25:50], z_levels_U, 'xr', label = "MD of Predicted")
    axes[2, 2].errorbar(mean_delta_of_pred_over_ics[25:50], z_levels_ImPsi, xerr = 2*std_delta_of_pred_over_ics[25:50], fmt = 'r', label = r"Values within $2\sigma$")
    axes[2, 2].legend(loc = 'upper right')
    axes[2, 2].set_title(r"MD of $\widehat{Im(\psi)}$ from 10000 Inferences $\forall$ ICs")
    axes[2, 2].set_xlabel(r"Deviation in $\Delta s$, $Im(\psi)$")
    axes[2, 2].set_ylabel("Vertical levels (km)")
    axes[2, 2].set_xlim(-2, 2)

    plt.suptitle(fr"Single Step Profile Comparisons and Mean Deviation $\mid$ {types_of_icss[i]}", fontsize=18)
    plt.tight_layout(rect=[0, 0, 1, 0.985])
    plt.show()
# Out:
# SSW Transitions A to B: 199, Mean Value: 18.12
# SSW Transitions B to A: 199, Mean Value: 7.97
# Non-SSW Transitions A: 199, Mean Value: 22.92
# Non-SSW Transitions B: 199, Mean Value: 1.77
# Randomly sampled time steps: (181, 329, 556, 756)
# 796 (796, 75)

# %%
upper_bound = 53.8 / 2.8935
lower_bound = 7.41
zonal_wind = real_data[:, 1, 63]

def detect_transitions_A_to_B(u_series, upper, lower):
    transitions = []
    transition_values = []
    i = 0
    while i < len(u_series) - 1:
        if u_series[i-1] > upper and u_series[i] <= upper:
            j = i + 1
            while j < len(u_series) and u_series[j] <= upper:
                if u_series[j] < lower:
                    transitions.append(i)
                    transition_values.append(u_series[i])
                    break
                j += 1
            i = j
        else:
            i += 1
    return np.array(transitions), np.array(transition_values)

def detect_transitions_B_to_A(u_series, upper, lower):
    transitions = []
    transition_values = []
    i = 0
    while i < len(u_series) - 1:
        if u_series[i-1] < lower and u_series[i] >= lower:
            j = i + 1
            while j < len(u_series) and u_series[j] >= lower:
                if u_series[j] > upper:
                    transitions.append(i)
                    transition_values.append(u_series[i])
                    break
                j += 1
            i = j
        else:
            i += 1
    return np.array(transitions), np.array(transition_values)

ssw_indices_A1, ssw_transition_values_A1 = detect_transitions_A_to_B(real_data[:, 1, 63], upper_bound, lower_bound)
ssw_indices_B1, ssw_transition_values_B1 = detect_transitions_B_to_A(real_data[:, 1, 63], upper_bound, lower_bound)

transition_indices = np.union1d(ssw_indices_A1, ssw_indices_B1)
total_len = len(real_data)
non_ssw_indices_A1 = np.where((real_data[:, 1, 63] > upper_bound) & (~np.isin(np.arange(total_len), transition_indices)))[0]
non_ssw_indices_B1 = np.where((real_data[:, 1, 63] < lower_bound) & (~np.isin(np.arange(total_len), transition_indices)))[0]

n_samples = min(len(ssw_indices_A1), len(ssw_indices_A1), len(non_ssw_indices_A1), len(non_ssw_indices_A1))

non_ssw_indices_A1 = np.random.choice(non_ssw_indices_A1, size=n_samples, replace=False)
non_ssw_indices_B1 = np.random.choice(non_ssw_indices_B1, size=n_samples, replace=False)
non_ssw_transition_values_A1 = zonal_wind[non_ssw_indices_A1]
non_ssw_transition_values_B1 = zonal_wind[non_ssw_indices_B1]

X = np.vstack([
        real_data[ssw_indices_A1, 1],
        real_data[ssw_indices_B1, 1],
        real_data[non_ssw_indices_A1, 1],
        real_data[non_ssw_indices_B1, 1],
    ]).astype(np.float32)

labels = (
    ["AB"] * len(ssw_indices_A1) +
    ["BA"] * len(ssw_indices_B1) +
    ["A"] * len(non_ssw_indices_A1) +
    ["B"] * len(non_ssw_indices_B1)
)

print(f"SSW Transitions A to B: {len(ssw_indices_A1)}, Mean Value: {np.mean(ssw_transition_values_A1):.2f}")
print(f"SSW Transitions B to A: {len(ssw_indices_B1)}, Mean Value: {np.mean(ssw_transition_values_B1):.2f}")
print(f"Non-SSW Transitions A: {len(non_ssw_indices_A1)}, Mean Value: {np.mean(non_ssw_transition_values_A1):.2f}")
print(f"Non-SSW Transitions B: {len(non_ssw_indices_B1)}, Mean Value: {np.mean(non_ssw_transition_values_B1):.2f}")

ics = []
ics.extend(ssw_indices_A1)
ics.extend(ssw_indices_B1)
ics.extend(non_ssw_indices_A1)
ics.extend(non_ssw_indices_B1)
ics = np.array(ics)
next_time_step = ics + 1

real_current = real_data[ics, 1, :]       
real_next = real_data[next_time_step, 1, :]    

num_of_ics = len(ssw_indices_A1) + len(ssw_indices_B1) + len(non_ssw_indices_A1) + len(non_ssw_indices_B1)
print(num_of_ics, X.shape)

X = (X - mean_psi) / std_psi
X = X[:, :50]

timesteps = 10000
initial_cond = torch.reshape(torch.tensor(X), [num_of_ics, num_variables])
z = torch.zeros([num_of_ics,latent_dim])
save = np.zeros((timesteps, num_of_ics, 75))

for timestep in range(timesteps):
    with torch.no_grad():
        z = torch.randn_like(z)
        y = model.decode(z.float().cuda(), initial_cond.float().cuda())
        y = y.detach().cpu().numpy()

    pred_next_denorm = y.squeeze() * std_psi.squeeze() + mean_psi.squeeze()
    save[timestep, :, :] = pred_next_denorm

# U profiles
U_current_real = real_current[:, 50:75]
U_next_real = real_next[:, 50:75]
U_next_pred = save[:, :, 50:75]

# Re(Psi) profiles
RePsi_current_real = real_current[:, 0:25]
RePsi_next_real = real_next[:, 0:25]
RePsi_next_pred = save[:, :, 0:25]

# Im(Psi) profiles
ImPsi_current_real = real_current[:, 25:50]
ImPsi_next_real = real_next[:, 25:50]
ImPsi_next_pred = save[:, :, 25:50]

# Mean over inferences
U_next_pred = np.mean(U_next_pred, axis=0)
RePsi_next_pred = np.mean(RePsi_next_pred, axis=0)
ImPsi_next_pred = np.mean(ImPsi_next_pred, axis=0)

# AB

print(U_next_pred.shape, U_next_real.shape)
U_next_pred_AB = U_next_pred[:199, :]
U_next_real_AB = U_next_real[:199, :]

RePsi_next_pred_AB = RePsi_next_pred[:199, :]
RePsi_next_real_AB = RePsi_next_real[:199, :]

ImPsi_next_pred_AB = ImPsi_next_pred[:199, :]
ImPsi_next_real_AB = ImPsi_next_real[:199, :]

# BA

U_next_pred_BA = U_next_pred[199:398, :]
U_next_real_BA = U_next_real[199:398, :]

RePsi_next_pred_BA = RePsi_next_pred[199:398, :]
RePsi_next_real_BA = RePsi_next_real[199:398, :]

ImPsi_next_pred_BA = ImPsi_next_pred[199:398, :]
ImPsi_next_real_BA = ImPsi_next_real[199:398, :]

# A

U_next_pred_A = U_next_pred[398:597, :]
U_next_real_A = U_next_real[398:597, :]

RePsi_next_pred_A = RePsi_next_pred[398:597, :]
RePsi_next_real_A = RePsi_next_real[398:597, :]

ImPsi_next_pred_A = ImPsi_next_pred[398:597, :]
ImPsi_next_real_A = ImPsi_next_real[398:597, :]

# B

U_next_pred_B = U_next_pred[598:, :]
U_next_real_B = U_next_real[598:, :]

RePsi_next_pred_B = RePsi_next_pred[598:, :]
RePsi_next_real_B = RePsi_next_real[598:, :]

ImPsi_next_pred_B = ImPsi_next_pred[598:, :]
ImPsi_next_real_B = ImPsi_next_real[598:, :]

# MSE Values for Plotting

U_mse_AB = np.mean((U_next_pred_AB - U_next_real_AB)**2, axis=0)
U_std_AB = np.std((U_next_pred_AB - U_next_real_AB)**2, axis=0)
RePsi_mse_AB = np.mean((RePsi_next_pred_AB - RePsi_next_real_AB)**2, axis=0)
RePsi_std_AB = np.std((RePsi_next_pred_AB - RePsi_next_real_AB)**2, axis=0)
ImPsi_mse_AB = np.mean((ImPsi_next_pred_AB - ImPsi_next_real_AB)**2, axis=0)
ImPsi_std_AB = np.std((ImPsi_next_pred_AB - ImPsi_next_real_AB)**2, axis=0)

U_mse_BA = np.mean((U_next_pred_BA - U_next_real_BA)**2, axis=0)
U_std_BA = np.std((U_next_pred_BA - U_next_real_BA)**2, axis=0)
RePsi_mse_BA = np.mean((RePsi_next_pred_BA - RePsi_next_real_BA)**2, axis=0)
RePsi_std_BA = np.std((RePsi_next_pred_BA - RePsi_next_real_BA)**2, axis=0)
ImPsi_mse_BA = np.mean((ImPsi_next_pred_BA - ImPsi_next_real_BA)**2, axis=0)
ImPsi_std_BA = np.std((ImPsi_next_pred_BA - ImPsi_next_real_BA)**2, axis=0)

U_mse_A = np.mean((U_next_pred_A - U_next_real_A)**2, axis=0)
U_std_A = np.std((U_next_pred_A - U_next_real_A)**2, axis=0)
RePsi_mse_A = np.mean((RePsi_next_pred_A - RePsi_next_real_A)**2, axis=0)
RePsi_std_A = np.std((RePsi_next_pred_A - RePsi_next_real_A)**2, axis=0)
ImPsi_mse_A = np.mean((ImPsi_next_pred_A - ImPsi_next_real_A)**2, axis=0)
ImPsi_std_A = np.std((ImPsi_next_pred_A - ImPsi_next_real_A)**2, axis=0)

U_mse_B = np.mean((U_next_pred_B - U_next_real_B)**2, axis=0)
U_std_B = np.std((U_next_pred_B - U_next_real_B)**2, axis=0)
RePsi_mse_B = np.mean((RePsi_next_pred_B - RePsi_next_real_B)**2, axis=0)
RePsi_std_B = np.std((RePsi_next_pred_B - RePsi_next_real_B)**2, axis=0)
ImPsi_mse_B = np.mean((ImPsi_next_pred_B - ImPsi_next_real_B)**2, axis=0)
ImPsi_std_B = np.std((ImPsi_next_pred_B - ImPsi_next_real_B)**2, axis=0)

# RMSE

U_rmse_AB = np.sqrt(np.sum(np.mean((U_next_pred_AB - U_next_real_AB)**2, axis=0)))
RePsi_rmse_AB = np.sqrt(np.sum(np.mean((RePsi_next_pred_AB - RePsi_next_real_AB)**2, axis=0)))
ImPsi_rmse_AB = np.sqrt(np.sum(np.mean((ImPsi_next_pred_AB - ImPsi_next_real_AB)**2, axis=0)))

U_rmse_BA = np.sqrt(np.sum(np.mean((U_next_pred_BA - U_next_real_BA)**2, axis=0)))
RePsi_rmse_BA = np.sqrt(np.sum(np.mean((RePsi_next_pred_BA - RePsi_next_real_BA)**2, axis=0)))
ImPsi_rmse_BA = np.sqrt(np.sum(np.mean((ImPsi_next_pred_BA - ImPsi_next_real_BA)**2, axis=0)))

U_rmse_A = np.sqrt(np.sum(np.mean((U_next_pred_A - U_next_real_A)**2, axis=0)))
RePsi_rmse_A = np.sqrt(np.sum(np.mean((RePsi_next_pred_A - RePsi_next_real_A)**2, axis=0)))
ImPsi_rmse_A = np.sqrt(np.sum(np.mean((ImPsi_next_pred_A - ImPsi_next_real_A)**2, axis=0)))

U_rmse_B = np.sqrt(np.sum(np.mean((U_next_pred_B - U_next_real_B)**2, axis=0)))
RePsi_rmse_B = np.sqrt(np.sum(np.mean((RePsi_next_pred_B - RePsi_next_real_B)**2, axis=0)))
ImPsi_rmse_B = np.sqrt(np.sum(np.mean((ImPsi_next_pred_B - ImPsi_next_real_B)**2, axis=0)))

# Plotting

print(U_rmse_AB.shape, RePsi_rmse_AB.shape, ImPsi_rmse_AB.shape, 
      U_mse_AB.shape, RePsi_mse_AB.shape, ImPsi_mse_AB.shape)

z_levels_U = np.linspace(0, 70, 25)
z_levels_RePsi = np.linspace(0, 70, 25)
z_levels_ImPsi = np.linspace(0, 70, 25)

U_rmse_list = [U_rmse_AB, U_rmse_BA, U_rmse_A, U_rmse_B]
RePsi_rmse_list = [RePsi_rmse_AB, RePsi_rmse_BA, RePsi_rmse_A, RePsi_rmse_B]
ImPsi_rmse_list = [ImPsi_rmse_AB, ImPsi_rmse_BA, ImPsi_rmse_A, ImPsi_rmse_B]

U_mse_list = [U_mse_AB, U_mse_BA, U_mse_A, U_mse_B]
RePsi_mse_list = [RePsi_mse_AB, RePsi_mse_BA, RePsi_mse_A, RePsi_mse_B]
ImPsi_mse_list = [ImPsi_mse_AB, ImPsi_mse_BA, ImPsi_mse_A, ImPsi_mse_B]

U_std_list = [U_std_AB, U_std_BA, U_std_A, U_std_B]
RePsi_std_list = [RePsi_std_AB, RePsi_std_BA, RePsi_std_A, RePsi_std_B]
ImPsi_std_list = [ImPsi_std_AB, ImPsi_std_BA, ImPsi_std_A, ImPsi_std_B]

rmse_list = []

for i in range(4):

    mean_rmse_U = U_rmse_list[i]
    mean_rmse_RePsi = RePsi_rmse_list[i]
    mean_rmse_ImPsi = ImPsi_rmse_list[i]

    mean_mse_U = U_mse_list[i]
    mean_mse_RePsi = RePsi_mse_list[i]
    mean_mse_ImPsi = ImPsi_mse_list[i]

    std_rmse_U = U_std_list[i]
    std_rmse_RePsi = RePsi_std_list[i]
    std_rmse_ImPsi = ImPsi_std_list[i]

    fig, axes = plt.subplots(1, 3, figsize=(24, 8))
    axes[0].plot(mean_mse_U, z_levels_U, 'xr', label = "Mean MSE of Predicted")
    axes[0].errorbar(mean_mse_U, z_levels_U, xerr = 2*std_rmse_U, fmt = 'r', label = fr"Values within $2\sigma$")
    axes[0].legend(loc = 'upper right')
    axes[0].set_title(f"MSE in $U$ Prediction over 10000 Inferences | RMSE: {mean_rmse_U:.4f}", fontsize=16)
    axes[0].set_xlabel(f"MSE in $U(m/s)$")
    axes[0].set_ylabel("Vertical levels (km)")
    axes[0].set_xlim(0, 16)
    axes[1].plot(mean_mse_RePsi, z_levels_RePsi, 'xr', label = "Mean MSE of Predicted")
    axes[1].errorbar(mean_mse_RePsi, z_levels_RePsi, xerr = 2*std_rmse_RePsi, fmt = 'r', label = fr"Values within $2\sigma$")
    axes[1].legend(loc = 'upper right')
    axes[1].set_title(fr"MSE in $Re(\psi)$ Prediction over 10000 Inferences | RMSE: {mean_rmse_RePsi:.4f}", fontsize=16)
    axes[1].set_xlabel(r"MSE in $Re(\psi)$")
    axes[1].set_ylabel("Vertical levels (km)")
    axes[1].set_xlim(0, 1)
    axes[2].plot(mean_mse_ImPsi, z_levels_ImPsi, 'xr', label = "Mean MSE of Predicted")
    axes[2].errorbar(mean_mse_ImPsi, z_levels_ImPsi, xerr = 2*std_rmse_ImPsi, fmt = 'r', label = fr"Values within $2\sigma$")
    axes[2].legend(loc = 'upper right')
    axes[2].set_title(fr"MSE in $Im(\psi)$ Prediction over 10000 Inferences | RMSE: {mean_rmse_ImPsi:.4f}", fontsize=16)
    axes[2].set_xlabel(r"MSE in $Im(\psi)$")
    axes[2].set_ylabel("Vertical levels (km)")
    axes[2].set_xlim(0, 1)
    
    mean_rmse = (mean_rmse_U + mean_rmse_RePsi + mean_rmse_ImPsi) / 3
    rmse_list.append(mean_rmse)
    
    if i == 0:
        plt.suptitle(fr"MSE of $U, Re(\psi), $ and $Im(\psi)$ $\forall$ ICs $\mid$ RMSE:${mean_rmse:.4f}$ $\mid$ Transition Points from Set A to Set B", fontsize = 30)
    elif i == 1:
        plt.suptitle(fr"MSE of $U, Re(\psi), $ and $Im(\psi)$ $\forall$ ICs $\mid$ RMSE:${mean_rmse:.4f}$ $\mid$ Transition Points from Set B to Set A", fontsize = 30)
    elif i == 2:
        plt.suptitle(fr"MSE of $U, Re(\psi), $ and $Im(\psi)$ $\forall$ ICs $\mid$ RMSE:${mean_rmse:.4f}$ $\mid$ Equilibrium Points a", fontsize = 30)
    else:
        plt.suptitle(fr"MSE of $U, Re(\psi), $ and $Im(\psi)$ $\forall$ ICs $\mid$ RMSE:${mean_rmse:.4f}$ $\mid$ Equilibrium Points b", fontsize = 30)
        
    plt.tight_layout(pad=1.5, w_pad=1.5, rect=[0.05, 0.0, 0.95, 1])
    plt.show()

total_rmse = np.mean(rmse_list)
print(f"Total RMSE over all categories: {total_rmse:.4f}")
# Out:
# SSW Transitions A to B: 199, Mean Value: 18.12
# SSW Transitions B to A: 199, Mean Value: 7.97
# Non-SSW Transitions A: 199, Mean Value: 22.81
# Non-SSW Transitions B: 199, Mean Value: 1.12
# 796 (796, 75)
# (796, 25) (796, 25)
# () () () (25,) (25,) (25,)
# Total RMSE over all categories: 1.6169
